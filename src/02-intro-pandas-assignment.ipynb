# %% [markdown]
# # Задание

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/school21/d2
# !pwd
import pandas as pd
data = pd.read_csv('../datasets/kaggle_survey_2022_responses.csv')
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/school21/d2
# /content/drive/MyDrive/school21/d2
# <ipython-input-1-d2d6885965df>:6: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../datasets/kaggle_survey_2022_responses.csv')

# %%
import pandas as pd

# %% [markdown]
# ## Task 1

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive/school21/d2
# !pwd
data = pd.read_csv('../datasets/kaggle_survey_2022_responses.csv')
name2question = data.iloc[0]
data.drop(0, inplace=True)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/MyDrive/school21/d2'
# /content/drive/MyDrive/school21/d2
# /content/drive/My Drive/school21/d2
# <ipython-input-3-d7cf176d535d>:5: DtypeWarning: Columns (0,208,225,255,257,260,270,271,277) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('../datasets/kaggle_survey_2022_responses.csv')

# %% [markdown]
# Узнай самый часто встречаемый возраст респондентов

# %%
name2question['Q2']
data['Q2']
data['Q2'].value_counts()

import numpy
data['Q2'].value_counts().idxmax()
# Out:
# '18-21'

# %% [markdown]
# ## Task 2

# %% [markdown]
# Посчитай долю женщин среди русских участников опроса, которые уже не студенты. Результат округли до двух цифр после запятой

# %%
al = data[(data['Q4'].str.contains('Russia')) &
    (data['Q5'] == 'No')]
al1 = al['Q3'].value_counts()
al1.index
round(al1['Woman'] / (al1['Man'] + al1['Woman']), 2)
# Out:
# 0.24

# %% [markdown]
# ## Task 3

# %% [markdown]
# Найди среднее время заполнения опроса в **минутах**. Результат округли до двух знаков после запятой

# %%
data['Duration (in seconds)']
data['Duration (in seconds)'] = data['Duration (in seconds)'].astype(int)
min = round ((data['Duration (in seconds)'].mean() / 60), 2)
print('Среднее время заполнения опроса: %s минут' % min)
# Out:
# Среднее время заполнения опроса: 168.17 минут

# %% [markdown]
# ## Task 4

# %% [markdown]
# Выведи топ-3 образовательных курса, которые указали респонденты. P.S Это вопрос Q6

# %%
q6_columns = [col for col in data.columns if col.startswith('Q6')]
q6_columns
data[q6_columns]
courses = data[q6_columns].melt(var_name='вопрос', value_vars=q6_columns)
courses
courses['value'].value_counts().iloc[:3]
# Out:
# Coursera                                                 9699
# University Courses (resulting in a university degree)    6780
# Kaggle Learn Courses                                     6628
# Name: value, dtype: int64

# %% [markdown]
# ## Task 5

# %% [markdown]
# Узнай топ-5 языков программирования, которые регулярно используют Data Scientists в своей работе

# %%
#print(name2question[name2question.str.contains('language', regex=False)])
q12_columns = [col for col in data.columns if col.startswith('Q12')]
q12_columns
data[q12_columns]
language = data[q12_columns].melt(var_name='вопрос', value_vars=q12_columns)
language['value'].value_counts().iloc[:5]
# Out:
# Python    18653
# SQL        9620
# R          4571
# C++        4549
# Java       3862
# Name: value, dtype: int64

# %% [markdown]
# ## Task 6

# %% [markdown]
# Узнай средний доход среди 'Data Scientist' специалистов и средний доход среди 'Machine Learning/ MLops Engineer' \
# Т.к. в колонке Q29 указан промежуток, то возьми среднее значение из промежутка.
#
# Например:
# - '15,000-19,999' - 17500,
# - '125,000-149,999' - 137500.
# - \> $1,000,000 - оставляем 1000000
#
# Средние доход **округли до целого.**

# %%
from statistics import mean
name2question.loc['Q29']
name2question.loc['Q23']


my_data = data[~data["Q29"].isna()][["Q23", "Q29"]]
my_data = my_data[my_data['Q23'].str.contains('Data Scientist') | my_data['Q23'].str.contains('Machine Learning/ MLops Engineer')]

my_data["salary"] = my_data["Q29"].astype(str).apply(lambda x: round(mean([int(y) for y in  x.strip("$>").replace(",", "").split("-")])))

my_data[["Q23", "salary"]].groupby(["Q23"]).mean().round()
# Out:
#                                    salary
# Q23
# Data Scientist                    70337.0
# Machine Learning/ MLops Engineer  67438.0

# %% [markdown]
# ## Дополнительно

# %% [markdown]
# Найди какой-нибудь интересный инсайт из этих данных. Пиши свои интересные инсайты в чат проекта с хэштегом.
# #инсайт
#
# Автор самого интересного инсайта получит p2p баллы. Поверь, они тебе понадобятся

# %%
# Код тут
